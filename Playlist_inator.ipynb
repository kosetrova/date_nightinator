# %%
import spotipy, json, urllib.request, webbrowser
import pandas as pd
import spotipy.util as util

# %%
credentials = "spotipy_keys.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
client_id = api_tokens["client_id"]
client_secret = api_tokens["client_secret"]
redirect = api_tokens["redirect"]
username = api_tokens["username"]

# %%
scope = 'user-read-private user-read-playback-state user-modify-playback-state playlist-modify-public'
auth = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)

# %%
sp = spotipy.Spotify(auth=auth)

# %%
user_input = [["Dynamic", "Epic", "Mysterious"],  ["Beef"], ["Thai", "Indian", "Korean"]]
date_vibe = user_input[0]
dietary_req = user_input[1]
pref_cuisines = user_input[2]

# %%
user_music = []
for tracks in date_vibe:
    user_music.append(tracks)
output_music = ', ' .join([str(element) for element in user_music])
print(output_music)
# Out:
# Dynamic, Epic, Mysterious

# %%
query = output_music
track_results = sp.search(q=query, type="track", limit=50)

# %%
tracks = track_results['tracks']['items']

# %%
tracks[0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nvFFLtv7ZqoTr83387uK4'},
#     'href': 'https://api.spotify.com/v1/artists/4nvFFLtv7ZqoTr83387uK4',
#     'id': '4nvFFLtv7ZqoTr83387uK4',
#     'name': 'Dynamicduo',
#     'type': 'artist',
#     'uri': 'spotify:artist:4nvFFLtv7ZqoTr83387uK4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6GEykX11lQqp92UVOQQCC7'},
#     'href': 'https://api.spotify.com/v1/artists/6GEykX11lQqp92UVOQQCC7',
#     'id': '6GEykX11lQqp92UVOQQCC7',
#     'name': 'DJ Premier',
#     'type': 'artist',
#     'uri': 'spotify:artist:6GEykX11lQqp92UVOQQCC7'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
# ...

# %%
track_selection_list = []
track_art = []

for song in tracks:
    track_selection_list.append(song['uri'])
    track_art.append(song['album']['images'][0]['url'])

# %%
my_playlist = sp.user_playlist_create(user=username, name='Date Night Playlist ♡', public=True, description="Dynamic")
results = sp.user_playlist_add_tracks(username, my_playlist['id'], track_selection_list)

# %%
print(my_playlist)
# Out:
# {'collaborative': False, 'description': 'Dynamic', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/4B4czMjElcKUz0vwMK1bZe'}, 'followers': {'href': None, 'total': 0}, 'href': 'https://api.spotify.com/v1/playlists/4B4czMjElcKUz0vwMK1bZe', 'id': '4B4czMjElcKUz0vwMK1bZe', 'images': [], 'name': 'Date Night Playlist ♡', 'owner': {'display_name': 'Kseniia Osetrova', 'external_urls': {'spotify': 'https://open.spotify.com/user/31lchvz2f3wofjexgf63k3xcpcy4'}, 'href': 'https://api.spotify.com/v1/users/31lchvz2f3wofjexgf63k3xcpcy4', 'id': '31lchvz2f3wofjexgf63k3xcpcy4', 'type': 'user', 'uri': 'spotify:user:31lchvz2f3wofjexgf63k3xcpcy4'}, 'primary_color': None, 'public': True, 'snapshot_id': 'MSwwMzU1NGUzYTU0ZjYzZGE2N2U3YzFlYjZlNTExNDFjYjE1MWY1ZmY3', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/4B4czMjElcKUz0vwMK1bZe/tracks', 'items': [], 'limit': 100, 'next': None, 'offset': 0, 'previous': None, 'total': 0}, 'type': 'playlist', 'uri': 'spotify:playlist:4B4czMjElcKUz0v
# ...

# %%
webbrowser.open(my_playlist['external_urls']['spotify'])
# Out:
# True
